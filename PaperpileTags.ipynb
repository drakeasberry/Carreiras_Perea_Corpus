# %%
import pandas as pd

# %%
data = pd.read_excel('keywords.xlsx')

# %%
data
# Out:
#                        Keywords
# 0                         /r-l/
# 1                /s/-aspiration
# 2                     acoustics
# 3                    activation
# 4           adjective agreement
# 5                      adoption
# 6              african-american
# 7               age of learning
# 8               age of learning
# 9                     allophone
# 10                   allophones
# 11    american higher education
# 12                   andalusian
# 13                 anticipation
# 14                      anxiety
# 15                       arabic
# 16                 articulation
# 17            aspect hypothesis
# 18                      aspects
# 19                    assessing
# 20          attention to speech
# 21   attentional control theory
# 22              audience design
# 23           audiovisual speech
# 24                 authenticity
# 25                 bayes factor
# 26                 bayes factor
# 27            bayesian analysis
# ...

# %%
data_unique = data.Keywords.unique()

# %%
data_unique
# Out:
# array(['/r-l/', '/s/-aspiration', 'acoustics', 'activation',
#        'adjective agreement', 'adoption', 'african-american',
#        'age of learning', 'allophone', 'allophones',
#        'american higher education', 'andalusian', 'anticipation',
#        'anxiety', 'arabic', 'articulation', 'aspect hypothesis',
#        'aspects', 'assessing', 'attention to speech',
#        'attentional control theory', 'audience design',
#        'audiovisual speech', 'authenticity', 'bayes factor',
#        'bayesian analysis', 'bayesian glmm', 'bayesian inference',
#        'bayesian model', 'behavior problems', 'bigrams', 'bilingualism',
#        'lexical access', 'lexical processing', 'lexicon',
#        'speech perception', 'word recognition', 'bimodal',
#        'brain development', 'call (computer-assisted language learning)',
#        'catalan', 'child protective services', 'child welfare',
#        'children', 'esl', 'clitics', 'coarticulation', 'code-switching',
# ...

# %%
len(data_unique)
# Out:
# 316

# %%
import re

# %%
str = 'This is all I need, all I want, and all I will ever have.'
x = re.findall("all",str)
print(x)
# Out:
# ['all', 'all', 'all']

# %%
for line in data_unique:
    if re.match('^bayes',line):
        print(line)
        newpattern = '"'+line+'"'
        print(newpattern)
        re.sub(newpattern,"bayesian")
        print(line)
    else: continue
# Out:
# bayes factor
# "bayes factor"
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-60ea0c32e25d> in <module>
#       4         newpattern = '"'+line+'"'
#       5         print(newpattern)
# ----> 6         re.sub(newpattern,"bayesian")
#       7         print(line)
#       8     else: continue
#
# TypeError: sub() missing 1 required positional argument: 'string'
